# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
model_prediction = pd.read_csv("closed_source\Results_one_shot_Gemini.csv")
model_prediction.head()
# Out:
#    Unnamed: 0                           text_string_conversation  \
# 0           0  customer: Hey, I saw your post about SmartLLM'...
# 1           1  customer: Hey, so, I've been looking into some...
# 2           2  customer: Hey, thanks for hopping on this call...
# 3           3  sales_rep: Hey Jessica, hope you're doing well...
# 4           4  customer: Hey, so I've been, like, struggling ...
#
#    ground_truth_conversion  gemini_probability
# 0                        1                0.65
# 1                        0                0.55
# 2                        1                0.75
# 3                        0                0.15
# 4                        0                0.15

# %%
from sklearn.metrics import roc_auc_score, classification_report, precision_recall_fscore_support

y_true = model_prediction['ground_truth_conversion'].values
y_prob = model_prediction['gemini_probability'].values

threshold = 0.5
y_pred = (y_prob >= threshold).astype(int)
print(f"\nThreshold: {threshold}")
print(classification_report(y_true, y_pred, target_names=['No Convert (0)', 'Convert (1)']))
# Out:
# Threshold: 0.5
#                 precision    recall  f1-score   support
#
# No Convert (0)       0.78      0.69      0.73       100
#    Convert (1)       0.72      0.80      0.76       100
#
#       accuracy                           0.74       200
#      macro avg       0.75      0.74      0.74       200
#   weighted avg       0.75      0.74      0.74       200
